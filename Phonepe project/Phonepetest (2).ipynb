# %%
import os
import json
import pandas as pd

# %%
path1 = "C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state"
agg_trans_list = os.listdir(path1)

# %%
agg_trans_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
path1 = "C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/"
agg_trans_list = os.listdir(path1) 

for state in agg_trans_list:
    cur_states =path1 + state +"/"
    print(cur_states)
# Out:
# C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/andaman-&-nicobar-islands/
# C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/andhra-pradesh/
# C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/arunachal-pradesh/
# C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/assam/
# C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/bihar/
# C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/chandigarh/
# C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/chhattisgarh/
# C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/
# ...

# %%
agg_year_list = os.listdir(cur_states)
print(agg_year_list)
# Out:
# ['2018', '2019', '2020', '2021', '2022', '2023']

# %%
path1 = "C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/"
agg_trans_list = os.listdir(path1) 

for state in agg_trans_list:
    cur_states =path1 + state +"/"
    agg_year_list = os.listdir(cur_states)
    print(agg_year_list)
# Out:
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ['2018', '2019', '2020', '2021', '2022', '2023']
# ...

# %%
path1 = "C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/"
agg_trans_list = os.listdir(path1) 

for state in agg_trans_list:
    cur_states =path1 + state +"/"
    agg_year_list = os.listdir(cur_states)

    for year in agg_year_list:
        cur_year =cur_states + year + "/"
        print(cur_year)
# Out:
# C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/andaman-&-nicobar-islands/2018/
# C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/andaman-&-nicobar-islands/2019/
# C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/andaman-&-nicobar-islands/2020/
# C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/andaman-&-nicobar-islands/2021/
# C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/andaman-&-nicobar-islands/2022/
# C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/andaman-&-nicobar-islands/2023/
# C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/andhra-pradesh/2018/
# ...

# %%
path1 = "C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/"
agg_trans_list = os.listdir(path1) 

for state in agg_trans_list:
    cur_states =path1 + state +"/"
    agg_year_list = os.listdir(cur_states)

    for year in agg_year_list:
        cur_year =cur_states + year + "/"
        agg_file_list = os.listdir(cur_year)
        print(agg_file_list)
# Out:
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ['1.json', '2.json', '3.json', '4.json']
# ...

# %%
path1 = "C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/"
agg_trans_list = os.listdir(path1) 

for state in agg_trans_list:
    cur_states =path1 + state +"/"
    agg_year_list = os.listdir(cur_states)

    for year in agg_year_list:
        cur_year =cur_states + year + "/"
        agg_file_list = os.listdir(cur_year)

        for file in agg_file_list:
            cur_file = cur_year + file
            data = open(cur_file,"r")

            A = json.load(data)

# %%
A
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'from': 1696098600000,
#   'to': 1703701800000,
#   'transactionData': [{'name': 'Merchant payments',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 354067997,
#       'amount': 239073842398.0}]},
#    {'name': 'Peer-to-peer payments',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 317959249,
#       'amount': 964138540494.0}]},
#    {'name': 'Recharge & bill payments',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 64920775,
#       'amount': 45319429210.0}]},
#    {'name': 'Financial Services',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 480740,
#       'amount': 459007296.0}]},
#    {'name': 'Others',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 524477,
#       'amount': 404156680.0}]}]},
#  'responseTimestamp': 1706092732267}

# %%
path1 = "C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/transaction/country/india/state/"
agg_trans_list = os.listdir(path1) 

clm = {"state":[], "year":[], "Quater":[], "Transaction_type":[], "Transaction_count":[], "Transaction_amount":[]} 
for state in agg_trans_list:
    cur_states =path1 + state +"/"
    agg_year_list = os.listdir(cur_states)

    for year in agg_year_list:
        cur_year =cur_states + year + "/"
        agg_file_list = os.listdir(cur_year)

        for file in agg_file_list:
            cur_file = cur_year + file
            data = open(cur_file,"r")

            A = json.load(data)

            for i in A["data"]["transactionData"]:
                name=i["name"]
                count=i["paymentInstruments"][0]["count"]
                amount=i["paymentInstruments"][0]["amount"]
                clm["Transaction_type"].append(name)
                clm["Transaction_count"].append(count)
                clm["Transaction_amount"].append(amount)
                clm["state"].append(state)
                clm["year"].append(year)
                clm["Quater"].append(int(file.strip(".json")))

# %%
agg_trans=pd.DataFrame(clm)

# %%
agg_trans["state"]=agg_trans["state"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar Islands")
agg_trans["state"]=agg_trans["state"].str.replace("-"," ")
agg_trans["state"]=agg_trans["state"].str.title()
agg_trans["state"]=agg_trans["state"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu")

# %%
agg_trans['year'] = agg_trans['year'].astype(int)
agg_trans.dtypes
# Out:
# state                  object
# year                    int32
# Quater                  int64
# Transaction_type       object
# Transaction_count       int64
# Transaction_amount    float64
# dtype: object

# %%
agg_trans
# Out:
#                           state  year  Quater          Transaction_type  \
# 0     Andaman & Nicobar Islands  2018       1  Recharge & bill payments
# 1     Andaman & Nicobar Islands  2018       1     Peer-to-peer payments
# 2     Andaman & Nicobar Islands  2018       1         Merchant payments
# 3     Andaman & Nicobar Islands  2018       1        Financial Services
# 4     Andaman & Nicobar Islands  2018       1                    Others
# ...                         ...   ...     ...                       ...
# 4309                West Bengal  2023       4         Merchant payments
# 4310                West Bengal  2023       4     Peer-to-peer payments
# 4311                West Bengal  2023       4  Recharge & bill payments
# 4312                West Bengal  2023       4        Financial Services
# 4313                West Bengal  2023       4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# ...

# %%
path2 = "C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/aggregated/user/country/india/state/"
agg_user_list = os.listdir(path2)
clm1 = {"state":[], "year":[], "Quater":[], "Brands":[], "Transaction_count":[], "Percentage":[]} 

for state in agg_user_list:
    cur_states =path2 + state +"/"
    agg_year_list = os.listdir(cur_states)

    for year in agg_year_list:
        cur_year =cur_states + year + "/"
        agg_file_list = os.listdir(cur_year)

        for file in agg_file_list:
            cur_file = cur_year + file
            data = open(cur_file,"r")

            B = json.load(data)

            try:
                for i in B["data"]["usersByDevice"]:
                    brand=i["brand"]
                    count=i["count"]
                    percentage=i["percentage"]
                    clm1["Brands"].append(brand)
                    clm1["Transaction_count"].append(count)
                    clm1["Percentage"].append(percentage)
                    clm1["state"].append(state)
                    clm1["year"].append(year)
                    clm1["Quater"].append(int(file.strip(".json")))

            except:
                pass

# %%
df2["state"]= df2["state"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar Islands")
df2["state"]= df2["state"].str.replace("-"," ")
df2["state"]=df2["state"].str.title()
df2["state"]=df2["state"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu")

# %%
df2['year'] = df2['year'].astype(int)
df2.dtypes
# Out:
# state                 object
# year                   int32
# Quater                 int64
# Brands                object
# Transaction_count      int64
# Percentage           float64
# dtype: object

# %%
df2
# Out:
#                           state  year  Quater   Brands  Transaction_count  \
# 0     Andaman & Nicobar Islands  2018       1   Xiaomi               1665
# 1     Andaman & Nicobar Islands  2018       1  Samsung               1445
# 2     Andaman & Nicobar Islands  2018       1     Vivo                982
# 3     Andaman & Nicobar Islands  2018       1     Oppo                501
# 4     Andaman & Nicobar Islands  2018       1  OnePlus                332
# ...                         ...   ...     ...      ...                ...
# 6727                West Bengal  2022       1   Lenovo             330017
# 6728                West Bengal  2022       1  Infinix             284678
# 6729                West Bengal  2022       1     Asus             280347
# 6730                West Bengal  2022       1    Apple             277752
# 6731                West Bengal  2022       1   Others            2196334
#
#       Percentage
# 0       0.247033
# 1       0.214392
# 2       0.145697
# ...

# %%
path3 = "C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/map/transaction/hover/country/india/state/"
map_trans_list = os.listdir(path3) 

clm2 = {"state":[], "year":[], "Quater":[], "Districts":[], "Transaction_count":[], "Transaction_amount":[]} 
for state in map_trans_list:
    cur_states =path3 + state +"/"
    agg_year_list = os.listdir(cur_states)

    for year in agg_year_list:
        cur_year =cur_states + year + "/"
        agg_file_list = os.listdir(cur_year)

        for file in agg_file_list:
            cur_file = cur_year + file
            data = open(cur_file,"r")

            C = json.load(data)

            for i in C["data"]["hoverDataList"]:
                name=i["name"]
                count=i["metric"][0]["count"]
                amount=i["metric"][0]["amount"]
                clm2["Districts"].append(name)
                clm2["Transaction_count"].append(count)
                clm2["Transaction_amount"].append(amount)
                clm2["state"].append(state)
                clm2["year"].append(year)
                clm2["Quater"].append(int(file.strip(".json")))

# %%
df3 = pd.DataFrame(clm2)

# %%
df3["state"]= df3["state"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar Islands")
df3["state"]= df3["state"].str.replace("-"," ")
df3["state"]=df3["state"].str.title()
df3["state"]=df3["state"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu")
df3["Districts"]=df3["Districts"].str.title()

# %%
df3['year'] = df3['year'].astype(int)
df3.dtypes
# Out:
# state                  object
# year                    int32
# Quater                  int64
# Districts              object
# Transaction_count       int64
# Transaction_amount    float64
# dtype: object

# %%
df3
# Out:
#                            state  year  Quater  \
# 0      Andaman & Nicobar Islands  2018       1
# 1      Andaman & Nicobar Islands  2018       1
# 2      Andaman & Nicobar Islands  2018       1
# 3      Andaman & Nicobar Islands  2018       2
# 4      Andaman & Nicobar Islands  2018       2
# ...                          ...   ...     ...
# 17559                West Bengal  2023       4
# 17560                West Bengal  2023       4
# 17561                West Bengal  2023       4
# 17562                West Bengal  2023       4
# 17563                West Bengal  2023       4
#
#                                Districts  Transaction_count  \
# 0      North And Middle Andaman District                442
# 1                 South Andaman District               5688
# 2                      Nicobars District                528
# 3      North And Middle Andaman District                825
# 4                 South Andaman District               9395
# ...

# %%
path4 = "C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/map/user/hover/country/india/state/"
map_user_list = os.listdir(path4)
clm3 = {"state":[], "year":[], "Quater":[], "Districts":[], "RegisteredUsers":[], "AppOpens":[]} 

for state in map_user_list:
    cur_states =path4 + state +"/"
    agg_year_list = os.listdir(cur_states)

    for year in agg_year_list:
        cur_year =cur_states + year + "/"
        agg_file_list = os.listdir(cur_year)

        for file in agg_file_list:
            cur_file = cur_year + file
            data = open(cur_file,"r")

            D = json.load(data)

            for i in D["data"]["hoverData"].items():
                districts=i[0]
                registeredUsers=i[1]["registeredUsers"]
                appOpens=i[1]["appOpens"]
                clm3["Districts"].append(districts)
                clm3["RegisteredUsers"].append(registeredUsers)
                clm3["AppOpens"].append(appOpens)
                clm3["state"].append(state)
                clm3["year"].append(year)
                clm3["Quater"].append(int(file.strip(".json")))

# %%
df4 =pd.DataFrame(clm3)

# %%
df4["state"]= df4["state"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar Islands")
df4["state"]= df4["state"].str.replace("-"," ")
df4["state"]=df4["state"].str.title()
df4["state"]=df4["state"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu")
df4["Districts"]=df4["Districts"].str.title()

# %%
df4['year'] = df4['year'].astype(int)
df4.dtypes
# Out:
# state              object
# year                int32
# Quater              int64
# Districts          object
# RegisteredUsers     int64
# AppOpens            int64
# dtype: object

# %%
df4
# Out:
#                            state  year  Quater  \
# 0      Andaman & Nicobar Islands  2018       1
# 1      Andaman & Nicobar Islands  2018       1
# 2      Andaman & Nicobar Islands  2018       1
# 3      Andaman & Nicobar Islands  2018       2
# 4      Andaman & Nicobar Islands  2018       2
# ...                          ...   ...     ...
# 17563                West Bengal  2023       4
# 17564                West Bengal  2023       4
# 17565                West Bengal  2023       4
# 17566                West Bengal  2023       4
# 17567                West Bengal  2023       4
#
#                                Districts  RegisteredUsers  AppOpens
# 0      North And Middle Andaman District              632         0
# 1                 South Andaman District             5846         0
# 2                      Nicobars District              262         0
# 3      North And Middle Andaman District              911         0
# ...

# %%
path5 = "C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/top/transaction/country/india/state/"
top_trans_list = os.listdir(path5) 

clm4 = {"state":[], "year":[], "Quater":[], "Pincodes":[], "Transaction_count":[], "Transaction_amount":[]} 
for state in top_trans_list:
    cur_states =path5 + state +"/"
    agg_year_list = os.listdir(cur_states)

    for year in agg_year_list:
        cur_year =cur_states + year + "/"
        agg_file_list = os.listdir(cur_year)

        for file in agg_file_list:
            cur_file = cur_year + file
            data = open(cur_file,"r")

            E = json.load(data)

            for i in E["data"]["pincodes"]:
                entityName=i["entityName"]
                count=i["metric"]["count"]
                amount=i["metric"]["amount"]
                clm4["Pincodes"].append(entityName)
                clm4["Transaction_count"].append(count)
                clm4["Transaction_amount"].append(amount)
                clm4["state"].append(state)
                clm4["year"].append(year)
                clm4["Quater"].append(int(file.strip(".json")))

# %%
df5=pd.DataFrame(clm4)

# %%
df5["state"]= df5["state"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar Islands")
df5["state"]= df5["state"].str.replace("-"," ")
df5["state"]=df5["state"].str.title()
df5["state"]=df5["state"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu")

# %%
df5['Pincodes'] = pd.to_numeric(df5['Pincodes'], errors='coerce')
df5.dtypes
# Out:
# state                  object
# year                    int32
# Quater                  int64
# Pincodes              float64
# Transaction_count       int64
# Transaction_amount    float64
# dtype: object

# %%
df5
# Out:
#                           state  year  Quater Pincodes  Transaction_count  \
# 0     Andaman & Nicobar Islands  2018       1   744101               1622
# 1     Andaman & Nicobar Islands  2018       1   744103               1223
# 2     Andaman & Nicobar Islands  2018       1   744102                969
# 3     Andaman & Nicobar Islands  2018       1   744105                685
# 4     Andaman & Nicobar Islands  2018       1   744104                340
# ...                         ...   ...     ...      ...                ...
# 8562                West Bengal  2023       4   721301            4133775
# 8563                West Bengal  2023       4   700001            3983241
# 8564                West Bengal  2023       4   732125            3950411
# 8565                West Bengal  2023       4   700039            3742452
# 8566                West Bengal  2023       4   700014            3652710
#
#       Transaction_amount
# 0           2.769298e+06
# 1           2.238042e+06
# ...

# %%
path6 = "C:/Users/aravi/Desktop/Python Scripts/Phonepe/pulse/data/top/user/country/india/state/"
top_user_list = os.listdir(path6)
clm5 = {"state":[], "year":[], "Quater":[], "Pincodes":[], "RegisteredUsers":[]} 

for state in top_user_list:
    cur_states =path6 + state +"/"
    agg_year_list = os.listdir(cur_states)

    for year in agg_year_list:
        cur_year =cur_states + year + "/"
        agg_file_list = os.listdir(cur_year)

        for file in agg_file_list:
            cur_file = cur_year + file
            data = open(cur_file,"r")

            F = json.load(data)

            for i in F["data"]["pincodes"]:
                entityName=i["name"]
                registeredUsers=i["registeredUsers"]
                clm5["Pincodes"].append(entityName)
                clm5["RegisteredUsers"].append(registeredUsers)
                clm5["state"].append(state)
                clm5["year"].append(year)
                clm5["Quater"].append(int(file.strip(".json")))

# %%
df6 = pd.DataFrame(clm5)

# %%
df6["state"]= df6["state"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar Islands")
df6["state"]= df6["state"].str.replace("-"," ")
df6["state"]=df6["state"].str.title()
df6["state"]=df6["state"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu")

# %%
df6
# Out:
#                           state  year  Quater Pincodes  RegisteredUsers
# 0     Andaman & Nicobar Islands  2018       1   744103             1608
# 1     Andaman & Nicobar Islands  2018       1   744101             1108
# 2     Andaman & Nicobar Islands  2018       1   744105             1075
# 3     Andaman & Nicobar Islands  2018       1   744102             1006
# 4     Andaman & Nicobar Islands  2018       1   744104              272
# ...                         ...   ...     ...      ...              ...
# 8563                West Bengal  2023       4   700015           126663
# 8564                West Bengal  2023       4   742304           123320
# 8565                West Bengal  2023       4   721101           123088
# 8566                West Bengal  2023       4   700150           119283
# 8567                West Bengal  2023       4   700091           118578
#
# [8568 rows x 5 columns]

# %%
df6['year'] = df6['year'].astype(int)
df6['Pincodes'] = df6['Pincodes'].astype(int)

# %%
df6.dtypes
# Out:
# state              object
# year                int32
# Quater              int64
# Pincodes            int32
# RegisteredUsers     int64
# dtype: object

# %%
df6
# Out:
#                           state  year  Quater  Pincodes  RegisteredUsers
# 0     Andaman & Nicobar Islands  2018       1    744103             1608
# 1     Andaman & Nicobar Islands  2018       1    744101             1108
# 2     Andaman & Nicobar Islands  2018       1    744105             1075
# 3     Andaman & Nicobar Islands  2018       1    744102             1006
# 4     Andaman & Nicobar Islands  2018       1    744104              272
# ...                         ...   ...     ...       ...              ...
# 8563                West Bengal  2023       4    700015           126663
# 8564                West Bengal  2023       4    742304           123320
# 8565                West Bengal  2023       4    721101           123088
# 8566                West Bengal  2023       4    700150           119283
# 8567                West Bengal  2023       4    700091           118578
#
# [8568 rows x 5 columns]

# %%
myconnection = pymysql.connect(host='127.0.0.1',user='GUVI',passwd='Bala@1968')

# %%
pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.5 MB 640.0 kB/s eta 0:00:23
#    ---------------------------------------- 0.1/14.5 MB 656.4 kB/s eta 0:00:22
#     --------------------------------------- 0.3/14.5 MB 2.2 MB/s eta 0:00:07
#    - -------------------------------------- 0.7/14.5 MB 3.8 MB/s eta 0:00:04
#    -- ------------------------------------- 1.0/14.5 MB 4.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.5/14.5 MB 5.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.0/14.5 MB 6.5 MB/s eta 0:00:02
#    ------ --------------------------------- 2.3/14.5 MB 6.6 MB/s eta 0:00:02
#    -------- ------------------------------- 2.9/14.5 MB 7.2 MB/s eta 0:00:02
#    -------- ------------------------------- 3.2/14.5 MB 7.3 MB/s eta 0:00:02
# ...

# %%
import mysql.connector

# %%
import pandas as pd

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

# Establish connection
myconnection = pymysql.connect(host='127.0.0.1', user='root', passwd='Bala@9944', database="myproject")
cursor = myconnection.cursor()

# Create table
create_table_sql = """
CREATE TABLE IF NOT EXISTS myproject.top_user (
    state VARCHAR(255),
    year INT,
    Quater BIGINT,
    Pincodes INT,
    RegisteredUsers BIGINT
)
"""
cursor.execute(create_table_sql)

# Insert data
sql = "INSERT INTO myproject.top_user VALUES (%s, %s, %s, %s, %s)"
for i in range(len(df6)):
    cursor.execute(sql, tuple(df6.iloc[i]))
    myconnection.commit()

# Close connection
myconnection.close()

# %%
myconnection = pymysql.connect(host='127.0.0.1', user='root', passwd='Bala@9944', database="myproject")
cursor = myconnection.cursor()

# Create table with modified schema
create_table_sql = """
CREATE TABLE IF NOT EXISTS myproject.top_transcation (
    state VARCHAR(255),
    year INT,
    Quater BIGINT,
    Pincodes INT, 
    Transaction_count BIGINT,
    Transaction_amount FLOAT
)
"""
cursor.execute(create_table_sql)

# Insert data
sql = "INSERT INTO myproject.top_transcation VALUES (%s, %s, %s, %s, %s, %s)"
for i in range(len(df5)):
    cursor.execute(sql, tuple(df5.iloc[i]))
    myconnection.commit()

# Close connection
myconnection.close()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# Cell In[96], line 20
#      18 sql = "INSERT INTO myproject.top_transcation VALUES (%s, %s, %s, %s, %s, %s)"
#      19 for i in range(len(df5)):
# ---> 20     cursor.execute(sql, tuple(df5.iloc[i]))
#      21     myconnection.commit()
#      23 # Close connection
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# ...

# %%
myconnection = pymysql.connect(host='127.0.0.1', user='root', passwd='Bala@9944', database="myproject")
cursor = myconnection.cursor()

# Create table
create_table_sql = """
CREATE TABLE IF NOT EXISTS myproject.map_user (
    state VARCHAR(255),
    year INT,
    Quater BIGINT,
    Districts VARCHAR(255),
    RegisteredUsers BIGINT,
    AppOpens BIGINT
)
"""
cursor.execute(create_table_sql)

# Insert data
sql = "INSERT INTO myproject.map_user VALUES (%s, %s, %s, %s, %s, %s)"
for i in range(len(df4)):
    cursor.execute(sql, tuple(df4.iloc[i]))
    myconnection.commit()

# Close connection
myconnection.close()

# %%
import pymysql

# Establish connection
myconnection = pymysql.connect(host='127.0.0.1', user='root', passwd='Bala@9944', database="myproject")
cursor = myconnection.cursor()

# Create table
create_table_sql = """
CREATE TABLE IF NOT EXISTS myproject.map_transcation (
    state VARCHAR(255),
    year INT,
    Quater BIGINT,
    Districts VARCHAR(255),
    Transaction_count BIGINT,
    Transaction_amount FLOAT
)
"""
cursor.execute(create_table_sql)

# Insert data
sql = "INSERT INTO myproject.map_transcation VALUES (%s, %s, %s, %s, %s, %s)"
for i in range(len(df3)):
    cursor.execute(sql, tuple(df3.iloc[i]))
    myconnection.commit()

# Close connection
myconnection.close()

# %%
import pymysql

# Establish connection
myconnection = pymysql.connect(host='127.0.0.1', user='root', passwd='Bala@9944', database="myproject")
cursor = myconnection.cursor()

# Create table
create_table_sql = """
CREATE TABLE IF NOT EXISTS myproject.agg_user (
    state VARCHAR(255),
    year INT,
    Quater BIGINT,
    Brands VARCHAR(255),
    Transaction_count BIGINT,
    Percentage FLOAT
)
"""
cursor.execute(create_table_sql)

# Insert data
sql = "INSERT INTO myproject.agg_user VALUES (%s, %s, %s, %s, %s, %s)"
for i in range(len(df2)):
    cursor.execute(sql, tuple(df2.iloc[i]))
    myconnection.commit()

# Close connection
myconnection.close()

# %%
import pymysql

# Establish connection
myconnection = pymysql.connect(host='127.0.0.1', user='root', passwd='Bala@9944', database="myproject")
cursor = myconnection.cursor()

# Create table
create_table_sql = """
CREATE TABLE IF NOT EXISTS myproject.agg_transaction (
    state VARCHAR(255),
    year INT,
    Quater BIGINT,
    Transaction_type VARCHAR(255),
    Transaction_count BIGINT,
    Transaction_amount FLOAT
)
"""
cursor.execute(create_table_sql)

# Insert data
sql = "INSERT INTO myproject.agg_transaction VALUES (%s, %s, %s, %s, %s, %s)"
for i in range(len(agg_trans)):
    cursor.execute(sql, tuple(agg_trans.iloc[i]))
    myconnection.commit()

# Close connection
myconnection.close()
